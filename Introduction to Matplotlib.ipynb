# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4,5]
y = [11,22,33,44,55]
plt.plot(x,y);

# %%
#1st method
fig = plt.figure() #create figure
ax = fig.add_subplot() #add some axes
plt.show()

# %%
#2nd method
fig = plt.figure() #create figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data
plt.show()

# %%
#3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y); #add some data

# %% [markdown]
# # Matplotlib example workflow

# %%
# step 0: import matplotlib and getting ready for jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# step 1: prepare data
x = [1,2,3,4]
y= [11,22,33,44]

# step 2: setup plot
fig, ax = plt.subplots(figsize=(10,10))

#step 3: plot data
ax.plot(x,y)

#step 4: customize plot
ax.set(title="simple plot",
      xlabel = "x axis",
      ylabel = "y axis")

#step 5: save amd show (you save the whole figure)
#fig.savefig("Pictures/Saved-Pictures/sample-plot.png")
# Out:
# [Text(0.5, 1.0, 'simple plot'), Text(0.5, 0, 'x axis'), Text(0, 0.5, 'y axis')]

# %% [markdown]
# # Making figures with numpy arrays
# we want-:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * subplot

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#creating the data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create the line plot
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
#use same data to make scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#make a plot from dictinory
nut_butter_prices = {"Almond Butter": 10,"Peanut Butter":8,"Cashew Butter": 12 }
fig, ax= plt.subplots()
ax.bar(nut_butter_prices.keys() , height = nut_butter_prices.values())
ax.set(title = "Dan's Nut Butter Store",ylabel = "Prices ($)")
# Out:
# [Text(0.5, 1.0, "Dan's Nut Butter Store"), Text(0, 0.5, 'Prices ($)')]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#make some data for histogram and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
#subplot option 1:
fig,((ax1, ax2),(ax3 , ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10,5))
#plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#option 2
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#plot to each different axis
ax[0, 0].plot(x,x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 4>()
#       2 fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#       3 #plot to each different axis
# ----> 4 ax[0, 0].plot(x,x/2);
#       5 ax[0, 1].scatter(np.random.random(10), np.random.random(10));
#       6 ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('01/01/2000',periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
#How about the bar graph?
x = np.random.rand(10,4)
x
#Turn it into a dataframe
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.247719  0.780715  0.780952  0.235444
# 1  0.989766  0.083693  0.231445  0.428543
# 2  0.942909  0.186731  0.185987  0.145608
# 3  0.268441  0.999337  0.460545  0.151018
# 4  0.596568  0.984237  0.425010  0.010146
# 5  0.069211  0.182282  0.449584  0.870713
# 6  0.628810  0.991322  0.907482  0.833196
# 7  0.796083  0.142550  0.644926  0.760223
# 8  0.977044  0.989018  0.050878  0.017796
# 9  0.413857  0.530878  0.673420  0.929214

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %% [markdown]
# # Which one should you use?(pyplot vs matplotlib OO method?)
# * when plotting something quickly, okay to use the pyplot method.
# * when plotting something advance, use the OO method

# %%
#1st method
fig = plt.figure() #create figure
ax = fig.add_subplot() #add some axes
plt.show()

# %%
car_sales = pd.read_csv("C:/Users/Piyush/Downloads/cardata.csv")
car_sales
# Out:
#      Make Colour  Odometer(KM)  Doors      Price
# 0  Toyota  White        150043      4   $4,000/-
# 1   Honda    Red         23007      4   $5,000/-
# 2  Toyota   Blue        134667      3   $7,000/-
# 3     BMW  Black        780008      5  $22,000/-
# 4  Nissan  White        340989      4   $3,500/-
# 5  Toyota  Green        123456      4   $4,000/-
# 6   Honda   Blue        765439      4   $6,000/-
# 7   Honda   Blue        676767      4   $7,000/-
# 8  Toyota  White        909090      4   $6,500/-
# 9  Nissan  White        787878      4   $3,500/-

# %%
#Remove price column symbols
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
# C:\Users\Piyush\AppData\Local\Temp\ipykernel_1300\2276578600.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer(KM)  Doors    Price
# 0  Toyota  White        150043      4   4000/-
# 1   Honda    Red         23007      4   5000/-
# 2  Toyota   Blue        134667      3   7000/-
# 3     BMW  Black        780008      5  22000/-
# 4  Nissan  White        340989      4   3500/-
# 5  Toyota  Green        123456      4   4000/-
# 6   Honda   Blue        765439      4   6000/-
# 7   Honda   Blue        676767      4   7000/-
# 8  Toyota  White        909090      4   6500/-
# 9  Nissan  White        787878      4   3500/-

# %%
car_sales.plot(x = 'Make', y = 'Odometer(KM)', kind='bar');

# %% [markdown]
# # HISTOGRAM

# %%
car_sales["Odometer(KM)"].plot.hist();
